# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time

# %%
electric_vehicle_title_df = pd.read_csv("Resources/electric_vehicle_title_registration.csv")
electric_vehicle_title_df.head(2)
# Out:
#       Clean Alternative Fuel Vehicle Type  VIN (1-10)  DOL Vehicle ID  \
# 0  Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C       142240136
# 1  Plug-in Hybrid Electric Vehicle (PHEV)  1G1RD6E47C       142240136
#
#    Model Year       Make Model Vehicle Primary Use  Electric Range  \
# 0        2012  CHEVROLET  Volt           Passenger            35.0
# 1        2012  CHEVROLET  Volt           Passenger            35.0
#
#    Odometer Reading                                      Odometer Code  ...  \
# 0                 0  Odometer reading is not collected at time of r...  ...
# 1                 0  Odometer reading is not collected at time of r...  ...
#
#   Meets 2019 HB 2042 Sale Price/Value Requirement  \
# 0                                           False
# 1                                           False
#
#    2019 HB 2042: Battery Range Requirement  \
# 0          Meets battery range requirement
# 1          Meets battery range requirement
#
# ...

# %%
electric_vehicle_title_df.columns
# Out:
# Index(['Clean Alternative Fuel Vehicle Type', 'VIN (1-10)', 'DOL Vehicle ID',
#        'Model Year', 'Make', 'Model', 'Vehicle Primary Use', 'Electric Range',
#        'Odometer Reading', 'Odometer Code', 'New or Used Vehicle',
#        'Sale Price', 'Sale Date', 'Base MSRP', 'Transaction Type',
#        'DOL Transaction Date', 'Transaction Year', 'County', 'City',
#        'State of Residence', 'Postal Code',
#        '2015 HB 2778 Exemption Eligibility',
#        '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Meets 2019 HB 2042 Electric Range Requirement',
#        'Meets 2019 HB 2042 Sale Date Requirement',
#        'Meets 2019 HB 2042 Sale Price/Value Requirement',
#        '2019 HB 2042: Battery Range Requirement',
#        '2019 HB 2042: Purchase Date Requirement',
#        '2019 HB 2042: Sale Price/Value Requirement',
#        'Electric Vehicle Fee Paid', 'Transportation Electrification Fee Paid',
# ...

# %%
#  git model year,make ,model electric range  batel
electric_title_colm =pd.DataFrame(['Model Year', 'Make', 'Model','Vehicle Primary Use'])
electric_title_colm
# Out:
#                      0
# 0           Model Year
# 1                 Make
# 2                Model
# 3  Vehicle Primary Use

# %%
# Load CSV file and turn it into PD DataFrames frist dataset
electric_vehicle_info_df = pd.read_csv("Resources/electric_vehicle.csv")
electric_vehicle_info_df
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EA0K   Thurston      Tumwater    WA      98512.0        2019
# 1       1N4BZ1DV4N     Island       Clinton    WA      98236.0        2022
# 2       5YJ3E1EA0L  Snohomish     Snohomish    WA      98290.0        2020
# 3       5YJ3E1EBXL       King       Seattle    WA      98134.0        2020
# 4       5YJSA1CP0D  Snohomish       Edmonds    WA      98020.0        2013
# ...            ...        ...           ...   ...          ...         ...
# 135033  5YJSA1E29L       King  Yarrow Point    WA      98004.0        2020
# 135034  5YJYGDEE7M       King        Burien    WA      98168.0        2021
# 135035  5YJSA1E51N     Pierce    Gig Harbor    WA      98335.0        2022
# 135036  KM8KMDAF3P      Grant       Ephrata    WA      98823.0        2023
# 135037  1FADP5CU4E     Kitsap  Port Orchard    WA      98366.0        2014
#
#            Make    Model                   Electric Vehicle Type  \
# ...

# %%
hybrid_df = pd.read_csv("Resources/Hybrid_Vehicle.csv")
hybrid_df
# Out:
#      Year_Month   Fuel_Category          County  Count
# 0       2020/07        Electric        ALLEGANY     29
# 1       2020/07        Electric    ANNE ARUNDEL   1587
# 2       2020/07        Electric       BALTIMORE   1508
# 3       2020/07        Electric  BALTIMORE CITY    770
# 4       2020/07        Electric         CALVERT    140
# ...         ...             ...             ...    ...
# 2833    2023/05  Plug-In Hybrid              WI      3
# 2834    2023/05  Plug-In Hybrid        WICOMICO    173
# 2835    2023/05  Plug-In Hybrid       WORCESTER    131
# 2836    2023/05  Plug-In Hybrid              WV     16
# 2837    2023/05  Plug-In Hybrid              WY      1
#
# [2838 rows x 4 columns]

# %%
electric_vehicle_title_df.columns
# Out:
# Index(['Clean Alternative Fuel Vehicle Type', 'VIN (1-10)', 'DOL Vehicle ID',
#        'Model Year', 'Make', 'Model', 'Vehicle Primary Use', 'Electric Range',
#        'Odometer Reading', 'Odometer Code', 'New or Used Vehicle',
#        'Sale Price', 'Sale Date', 'Base MSRP', 'Transaction Type',
#        'DOL Transaction Date', 'Transaction Year', 'County', 'City',
#        'State of Residence', 'Postal Code',
#        '2015 HB 2778 Exemption Eligibility',
#        '2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility',
#        'Meets 2019 HB 2042 Electric Range Requirement',
#        'Meets 2019 HB 2042 Sale Date Requirement',
#        'Meets 2019 HB 2042 Sale Price/Value Requirement',
#        '2019 HB 2042: Battery Range Requirement',
#        '2019 HB 2042: Purchase Date Requirement',
#        '2019 HB 2042: Sale Price/Value Requirement',
#        'Electric Vehicle Fee Paid', 'Transportation Electrification Fee Paid',
# ...

# %%
sub_columns_df = electric_vehicle_title_df ["Model Year"].value_counts()
sub_columns_df
# Out:
# 2018    97038
# 2022    73925
# 2017    69879
# 2021    69408
# 2013    69008
# 2019    61641
# 2015    56725
# 2016    54708
# 2020    54049
# 2023    45258
# 2014    45017
# 2012    27473
# 2011    14841
# 2010      557
# 2008      378
# 2000      129
# 2024       60
# 1999       57
# 2002       44
# 1998       30
# 1997       21
# 2001       14
# 2003        7
# 1993        4
# 1994        3
# Name: Model Year, dtype: int64

# %%
sub_columns_df= electric_vehicle_title_df['Sale Price']
sub_columns_df
# Out:
# 0             0
# 1             0
# 2         55000
# 3             0
# 4             0
#           ...
# 740269        0
# 740270        0
# 740271        0
# 740272        0
# 740273        0
# Name: Sale Price, Length: 740274, dtype: int64

# %%
sub_columns_df= electric_vehicle_title_df['Sale Price'].value_counts()
sub_columns_df
# Out:
# 0        577888
# 35000      1160
# 51290       679
# 52440       675
# 54290       668
#           ...
# 39623         1
# 49868         1
# 37268         1
# 8912          1
# 33041         1
# Name: Sale Price, Length: 34749, dtype: int64

# %%
# Get the electric_vehicle_info_df columns.
electric_vehicle_info_df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
sub_columns_df=electric_vehicle_info_df['Electric Vehicle Type']
sub_columns_df
# Out:
# 0                 Battery Electric Vehicle (BEV)
# 1                 Battery Electric Vehicle (BEV)
# 2                 Battery Electric Vehicle (BEV)
# 3                 Battery Electric Vehicle (BEV)
# 4                 Battery Electric Vehicle (BEV)
#                            ...
# 135033            Battery Electric Vehicle (BEV)
# 135034            Battery Electric Vehicle (BEV)
# 135035            Battery Electric Vehicle (BEV)
# 135036            Battery Electric Vehicle (BEV)
# 135037    Plug-in Hybrid Electric Vehicle (PHEV)
# Name: Electric Vehicle Type, Length: 135038, dtype: object

# %%
sub_columns_df=electric_vehicle_info_df['Vehicle Location']
sub_columns_df

# %%
sub_columns_df=electric_vehicle_info_df['Make']
sub_columns_df
# Out:
# 0           TESLA
# 1          NISSAN
# 2           TESLA
# 3           TESLA
# 4           TESLA
#            ...
# 135033      TESLA
# 135034      TESLA
# 135035      TESLA
# 135036    HYUNDAI
# 135037       FORD
# Name: Make, Length: 135038, dtype: object

# %%
sub_columns_df=electric_vehicle_info_df['Make']
sub_columns_df
# Out:
# 0           TESLA
# 1          NISSAN
# 2           TESLA
# 3           TESLA
# 4           TESLA
#            ...
# 135033      TESLA
# 135034      TESLA
# 135035      TESLA
# 135036    HYUNDAI
# 135037       FORD
# Name: Make, Length: 135038, dtype: object
